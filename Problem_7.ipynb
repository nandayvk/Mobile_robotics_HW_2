# %% [markdown]
# ## Problem 7:

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
def derfunc(y, t):
    g = 32 # ft/s^2 
    L = 2 # ft 
    x1, x2 = y
    ydot = [0,0] 
    ydot[0] = x2
    ydot[1] = -g*math.sin(x1)/L
    return ydot

# %%
y0 = [0, 10]
t = np.linspace(0, 1, 100)

# %%
sol = odeint(derfunc, y0, t)

# %%
plt.plot(t, sol[:, 0], 'b', label='Pendulum angle(x1)')
plt.legend(loc='best')
plt.xlabel('t')
plt.ylabel('Pendulum angle(x1)')
plt.show()

# %%
plt.plot(t, sol[:, 1], 'g', label='pendulum angular velocity(x2)')
plt.legend(loc='best')
plt.xlabel('t')
plt.ylabel('Pendulum anglular velocity(x2)')
plt.show()
